# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
house = pd.read_csv("C:\\Users\\User\\Downloads\\resale price document.csv")

# %%
house
# Out:
#           month        town  flat_type block        street_name storey_range  \
# 0       2017-01  ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1       2017-01  ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2       2017-01  ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3       2017-01  ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4       2017-01  ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
# ...         ...         ...        ...   ...                ...          ...
# 168473  2023-12      YISHUN  EXECUTIVE   606       YISHUN ST 61     07 TO 09
# 168474  2023-12      YISHUN  EXECUTIVE   643       YISHUN ST 61     10 TO 12
# 168475  2023-12      YISHUN  EXECUTIVE   643       YISHUN ST 61     10 TO 12
# 168476  2023-12      YISHUN  EXECUTIVE   826       YISHUN ST 81     01 TO 03
# 168477  2023-12      YISHUN  EXECUTIVE   834       YISHUN ST 81     01 TO 03
#
#         floor_area_sqm      flat_model  lease_commence_date  \
# 0                 44.0        Improved                 1979
# 1                 67.0  New Generation                 1978
# 2                 67.0  New Generation                 1980
# 3                 68.0  New Generation                 1980
# 4                 67.0  New Generation                 1980
# ...                ...             ...                  ...
# 168473           142.0       Apartment                 1987
# 168474           146.0      Maisonette                 1987
# 168475           142.0       Apartment                 1987
# 168476           142.0       Apartment                 1988
# 168477           142.0       Apartment                 1988
#
#            remaining_lease  resale_price
# 0       61 years 04 months      232000.0
# 1       60 years 07 months      250000.0
# 2       62 years 05 months      262000.0
# 3        62 years 01 month      265000.0
# 4       62 years 05 months      265000.0
# ...                    ...           ...
# 168473   63 years 01 month      788888.0
# 168474  62 years 10 months      838000.0
# 168475  62 years 10 months      755000.0
# 168476  63 years 02 months      780000.0
# 168477  63 years 02 months      785000.0
#
# [168478 rows x 11 columns]

# %%
# checking dataset shape
house.shape
# Out:
# (168478, 11)

# %%
# checking the datatypes
house.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# remaining_lease         object
# resale_price           float64
# dtype: object

# %%
# checking the null values in dataset
house.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining_lease        0
# resale_price           0
# dtype: int64

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168478 entries, 0 to 168477
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                168478 non-null  object
#  1   town                 168478 non-null  object
#  2   flat_type            168478 non-null  object
#  3   block                168478 non-null  object
#  4   street_name          168478 non-null  object
#  5   storey_range         168478 non-null  object
#  6   floor_area_sqm       168478 non-null  float64
#  7   flat_model           168478 non-null  object
#  8   lease_commence_date  168478 non-null  int64
#  9   remaining_lease      168478 non-null  object
#  10  resale_price         168478 non-null  float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 14.1+ MB

# %%
#descriptive statistics analaysis

house.describe().T
# Out:
#                         count           mean            std       min  \
# floor_area_sqm       168478.0      97.295905      24.021881      31.0
# lease_commence_date  168478.0    1995.849399      13.937598    1966.0
# resale_price         168478.0  490609.627139  169704.579381  140000.0
#
#                           25%       50%       75%        max
# floor_area_sqm           82.0      93.0     112.0      249.0
# lease_commence_date    1985.0    1996.0    2009.0     2022.0
# resale_price         365000.0  460000.0  582000.0  1500000.0

# %%
# checking the unique values in flat_type feature
house['flat_type'].value_counts()
# Out:
# flat_type
# 4 ROOM              70943
# 5 ROOM              42123
# 3 ROOM              39771
# EXECUTIVE           12662
# 2 ROOM               2842
# MULTI-GENERATION       73
# 1 ROOM                 64
# Name: count, dtype: int64

# %%
# checking the unique values in town feature
house['town'].value_counts()
# Out:
# town
# SENGKANG           14085
# PUNGGOL            12529
# WOODLANDS          11921
# YISHUN             11541
# TAMPINES           11221
# JURONG WEST        11047
# BEDOK               9006
# HOUGANG             8403
# CHOA CHU KANG       7694
# ANG MO KIO          7003
# BUKIT MERAH         6470
# BUKIT PANJANG       6273
# BUKIT BATOK         6148
# TOA PAYOH           5314
# PASIR RIS           5064
# KALLANG/WHAMPOA     5058
# QUEENSTOWN          4691
# SEMBAWANG           4485
# GEYLANG             4177
# CLEMENTI            3814
# JURONG EAST         3445
# BISHAN              3121
# SERANGOON           3101
# CENTRAL AREA        1383
# MARINE PARADE       1061
# BUKIT TIMAH          423
# Name: count, dtype: int64

# %%
house['storey_range'].value_counts()
# Out:
# storey_range
# 04 TO 06    38726
# 07 TO 09    35357
# 10 TO 12    31492
# 01 TO 03    29688
# 13 TO 15    16110
# 16 TO 18     7604
# 19 TO 21     3238
# 22 TO 24     2330
# 25 TO 27     1398
# 28 TO 30      920
# 31 TO 33      483
# 34 TO 36      443
# 37 TO 39      391
# 40 TO 42      187
# 43 TO 45       56
# 46 TO 48       40
# 49 TO 51       15
# Name: count, dtype: int64

# %%
house['flat_model'].value_counts()
# Out:
# flat_model
# Model A                   58023
# Improved                  41600
# New Generation            21019
# Premium Apartment         19197
# Simplified                 6524
# Apartment                  6354
# Maisonette                 4816
# Standard                   4675
# DBSS                       2899
# Model A2                   1930
# Model A-Maisonette          303
# Adjoined flat               299
# Type S1                     291
# Type S2                     156
# Premium Apartment Loft       98
# Terrace                      92
# Multi Generation             73
# 2-room                       68
# Improved-Maisonette          25
# 3Gen                         22
# Premium Maisonette           14
# Name: count, dtype: int64

# %%
house.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date',
#        'remaining_lease', 'resale_price'],
#       dtype='object')

# %%
# Convert the 'month' column to a datetime format
house['month'] = pd.to_datetime(house['month'])

# Extract the year and month into separate columns
house['year'] = house['month'].dt.year
house['month_of_year'] = house['month'].dt.month
house
# Out:
#             month        town  flat_type block        street_name  \
# 0      2017-01-01  ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10
# 1      2017-01-01  ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4
# 2      2017-01-01  ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5
# 3      2017-01-01  ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10
# 4      2017-01-01  ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5
# ...           ...         ...        ...   ...                ...
# 168473 2023-12-01      YISHUN  EXECUTIVE   606       YISHUN ST 61
# 168474 2023-12-01      YISHUN  EXECUTIVE   643       YISHUN ST 61
# 168475 2023-12-01      YISHUN  EXECUTIVE   643       YISHUN ST 61
# 168476 2023-12-01      YISHUN  EXECUTIVE   826       YISHUN ST 81
# 168477 2023-12-01      YISHUN  EXECUTIVE   834       YISHUN ST 81
#
#        storey_range  floor_area_sqm      flat_model  lease_commence_date  \
# 0          10 TO 12            44.0        Improved                 1979
# 1          01 TO 03            67.0  New Generation                 1978
# 2          01 TO 03            67.0  New Generation                 1980
# 3          04 TO 06            68.0  New Generation                 1980
# 4          01 TO 03            67.0  New Generation                 1980
# ...             ...             ...             ...                  ...
# 168473     07 TO 09           142.0       Apartment                 1987
# 168474     10 TO 12           146.0      Maisonette                 1987
# 168475     10 TO 12           142.0       Apartment                 1987
# 168476     01 TO 03           142.0       Apartment                 1988
# 168477     01 TO 03           142.0       Apartment                 1988
#
#            remaining_lease  resale_price  year  month_of_year
# 0       61 years 04 months      232000.0  2017              1
# 1       60 years 07 months      250000.0  2017              1
# 2       62 years 05 months      262000.0  2017              1
# 3        62 years 01 month      265000.0  2017              1
# 4       62 years 05 months      265000.0  2017              1
# ...                    ...           ...   ...            ...
# 168473   63 years 01 month      788888.0  2023             12
# 168474  62 years 10 months      838000.0  2023             12
# 168475  62 years 10 months      755000.0  2023             12
# 168476  63 years 02 months      780000.0  2023             12
# 168477  63 years 02 months      785000.0  2023             12
#
# [168478 rows x 13 columns]

# %%
house.dtypes
# Out:
# month                  datetime64[ns]
# town                           object
# flat_type                      object
# block                          object
# street_name                    object
# storey_range                   object
# floor_area_sqm                float64
# flat_model                     object
# lease_commence_date             int64
# remaining_lease                object
# resale_price                  float64
# year                            int32
# month_of_year                   int32
# dtype: object

# %%
house['lease_commence_year'] = pd.to_datetime(house['lease_commence_date'],format = '%Y').dt.year
# Extract the year of lease commencement
#house['lease_commence_year'] = house['lease_commence_date'].dt.year

# %%
house
# Out:
#             month        town  flat_type block        street_name  \
# 0      2017-01-01  ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10
# 1      2017-01-01  ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4
# 2      2017-01-01  ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5
# 3      2017-01-01  ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10
# 4      2017-01-01  ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5
# ...           ...         ...        ...   ...                ...
# 168473 2023-12-01      YISHUN  EXECUTIVE   606       YISHUN ST 61
# 168474 2023-12-01      YISHUN  EXECUTIVE   643       YISHUN ST 61
# 168475 2023-12-01      YISHUN  EXECUTIVE   643       YISHUN ST 61
# 168476 2023-12-01      YISHUN  EXECUTIVE   826       YISHUN ST 81
# 168477 2023-12-01      YISHUN  EXECUTIVE   834       YISHUN ST 81
#
#        storey_range  floor_area_sqm      flat_model  lease_commence_date  \
# 0          10 TO 12            44.0        Improved                 1979
# 1          01 TO 03            67.0  New Generation                 1978
# 2          01 TO 03            67.0  New Generation                 1980
# 3          04 TO 06            68.0  New Generation                 1980
# 4          01 TO 03            67.0  New Generation                 1980
# ...             ...             ...             ...                  ...
# 168473     07 TO 09           142.0       Apartment                 1987
# 168474     10 TO 12           146.0      Maisonette                 1987
# 168475     10 TO 12           142.0       Apartment                 1987
# 168476     01 TO 03           142.0       Apartment                 1988
# 168477     01 TO 03           142.0       Apartment                 1988
#
#            remaining_lease  resale_price  year  month_of_year  \
# 0       61 years 04 months      232000.0  2017              1
# 1       60 years 07 months      250000.0  2017              1
# 2       62 years 05 months      262000.0  2017              1
# 3        62 years 01 month      265000.0  2017              1
# 4       62 years 05 months      265000.0  2017              1
# ...                    ...           ...   ...            ...
# 168473   63 years 01 month      788888.0  2023             12
# 168474  62 years 10 months      838000.0  2023             12
# 168475  62 years 10 months      755000.0  2023             12
# 168476  63 years 02 months      780000.0  2023             12
# 168477  63 years 02 months      785000.0  2023             12
#
#         lease_commence_year
# 0                      1979
# 1                      1978
# 2                      1980
# 3                      1980
# 4                      1980
# ...                     ...
# 168473                 1987
# 168474                 1987
# 168475                 1987
# 168476                 1988
# 168477                 1988
#
# [168478 rows x 14 columns]

# %%
house.dtypes
# Out:
# month                  datetime64[ns]
# town                           object
# flat_type                      object
# block                          object
# street_name                    object
# storey_range                   object
# floor_area_sqm                float64
# flat_model                     object
# lease_commence_date             int64
# remaining_lease                object
# resale_price                  float64
# year                            int32
# month_of_year                   int32
# lease_commence_year             int32
# dtype: object

# %%
# Extract the remaining_lease feature

data = house['remaining_lease']
house_new = pd.DataFrame(data)

# Extract years and months using regular expressions
lease_info = house['remaining_lease'].str.extract(r'(\d+) years (\d+) months')
lease_info.columns = ['years', 'months']

# Convert to numeric values
house['remaining_lease_years'] = pd.to_numeric(lease_info['years'])
house['remaining_lease_months'] = pd.to_numeric(lease_info['months'])

# %%
house_new_data = house.copy()

# %%
house_new_data
# Out:
#             month        town  flat_type block        street_name  \
# 0      2017-01-01  ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10
# 1      2017-01-01  ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4
# 2      2017-01-01  ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5
# 3      2017-01-01  ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10
# 4      2017-01-01  ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5
# ...           ...         ...        ...   ...                ...
# 168473 2023-12-01      YISHUN  EXECUTIVE   606       YISHUN ST 61
# 168474 2023-12-01      YISHUN  EXECUTIVE   643       YISHUN ST 61
# 168475 2023-12-01      YISHUN  EXECUTIVE   643       YISHUN ST 61
# 168476 2023-12-01      YISHUN  EXECUTIVE   826       YISHUN ST 81
# 168477 2023-12-01      YISHUN  EXECUTIVE   834       YISHUN ST 81
#
#        storey_range  floor_area_sqm      flat_model  lease_commence_date  \
# 0          10 TO 12            44.0        Improved                 1979
# 1          01 TO 03            67.0  New Generation                 1978
# 2          01 TO 03            67.0  New Generation                 1980
# 3          04 TO 06            68.0  New Generation                 1980
# 4          01 TO 03            67.0  New Generation                 1980
# ...             ...             ...             ...                  ...
# 168473     07 TO 09           142.0       Apartment                 1987
# 168474     10 TO 12           146.0      Maisonette                 1987
# 168475     10 TO 12           142.0       Apartment                 1987
# 168476     01 TO 03           142.0       Apartment                 1988
# 168477     01 TO 03           142.0       Apartment                 1988
#
#            remaining_lease  resale_price  year  month_of_year  \
# 0       61 years 04 months      232000.0  2017              1
# 1       60 years 07 months      250000.0  2017              1
# 2       62 years 05 months      262000.0  2017              1
# 3        62 years 01 month      265000.0  2017              1
# 4       62 years 05 months      265000.0  2017              1
# ...                    ...           ...   ...            ...
# 168473   63 years 01 month      788888.0  2023             12
# 168474  62 years 10 months      838000.0  2023             12
# 168475  62 years 10 months      755000.0  2023             12
# 168476  63 years 02 months      780000.0  2023             12
# 168477  63 years 02 months      785000.0  2023             12
#
#         lease_commence_year  remaining_lease_years  remaining_lease_months
# 0                      1979                   61.0                     4.0
# 1                      1978                   60.0                     7.0
# 2                      1980                   62.0                     5.0
# 3                      1980                    NaN                     NaN
# 4                      1980                   62.0                     5.0
# ...                     ...                    ...                     ...
# 168473                 1987                    NaN                     NaN
# 168474                 1987                   62.0                    10.0
# 168475                 1987                   62.0                    10.0
# 168476                 1988                   63.0                     2.0
# 168477                 1988                   63.0                     2.0
#
# [168478 rows x 16 columns]

# %%
house_new_data.isnull().sum()
# Out:
# month                         0
# town                          0
# flat_type                     0
# block                         0
# street_name                   0
# storey_range                  0
# floor_area_sqm                0
# flat_model                    0
# lease_commence_date           0
# remaining_lease               0
# resale_price                  0
# year                          0
# month_of_year                 0
# lease_commence_year           0
# remaining_lease_years     27535
# remaining_lease_months    27535
# dtype: int64

# %%
# handleing the null values using mean method
house_new_data['remaining_lease_years'].fillna(house['remaining_lease_years'].mean(),inplace = True)
house_new_data['remaining_lease_months'].fillna(house['remaining_lease_months'].mean(),inplace = True)
house_new_data.isnull().sum()
# Out:
# month                     0
# town                      0
# flat_type                 0
# block                     0
# street_name               0
# storey_range              0
# floor_area_sqm            0
# flat_model                0
# lease_commence_date       0
# remaining_lease           0
# resale_price              0
# year                      0
# month_of_year             0
# lease_commence_year       0
# remaining_lease_years     0
# remaining_lease_months    0
# dtype: int64

# %%
#  dropping the existing features 

house_new_data.drop(columns=['month','lease_commence_date','remaining_lease'],inplace = True)

# %%
house_new_data
# Out:
#               town  flat_type block        street_name storey_range  \
# 0       ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1       ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2       ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3       ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4       ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
# ...            ...        ...   ...                ...          ...
# 168473      YISHUN  EXECUTIVE   606       YISHUN ST 61     07 TO 09
# 168474      YISHUN  EXECUTIVE   643       YISHUN ST 61     10 TO 12
# 168475      YISHUN  EXECUTIVE   643       YISHUN ST 61     10 TO 12
# 168476      YISHUN  EXECUTIVE   826       YISHUN ST 81     01 TO 03
# 168477      YISHUN  EXECUTIVE   834       YISHUN ST 81     01 TO 03
#
#         floor_area_sqm      flat_model  resale_price  year  month_of_year  \
# 0                 44.0        Improved      232000.0  2017              1
# 1                 67.0  New Generation      250000.0  2017              1
# 2                 67.0  New Generation      262000.0  2017              1
# 3                 68.0  New Generation      265000.0  2017              1
# 4                 67.0  New Generation      265000.0  2017              1
# ...                ...             ...           ...   ...            ...
# 168473           142.0       Apartment      788888.0  2023             12
# 168474           146.0      Maisonette      838000.0  2023             12
# 168475           142.0       Apartment      755000.0  2023             12
# 168476           142.0       Apartment      780000.0  2023             12
# 168477           142.0       Apartment      785000.0  2023             12
#
#         lease_commence_year  remaining_lease_years  remaining_lease_months
# 0                      1979              61.000000                4.000000
# 1                      1978              60.000000                7.000000
# 2                      1980              62.000000                5.000000
# 3                      1980              74.123433                6.534301
# 4                      1980              62.000000                5.000000
# ...                     ...                    ...                     ...
# 168473                 1987              74.123433                6.534301
# 168474                 1987              62.000000               10.000000
# 168475                 1987              62.000000               10.000000
# 168476                 1988              63.000000                2.000000
# 168477                 1988              63.000000                2.000000
#
# [168478 rows x 13 columns]

# %% [markdown]
# # DATA PREPROCESSING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
house_new_data['town'] = encoder.fit_transform(house_new_data['town'])
house_new_data['flat_type'] = encoder.fit_transform(house_new_data['flat_type'])
house_new_data['storey_range'] = encoder.fit_transform(house_new_data['storey_range'])
house_new_data['flat_model'] = encoder.fit_transform(house_new_data['flat_model'])

# %%
house_new_data
# Out:
#         town  flat_type block        street_name  storey_range  \
# 0          0          1   406  ANG MO KIO AVE 10             3
# 1          0          2   108   ANG MO KIO AVE 4             0
# 2          0          2   602   ANG MO KIO AVE 5             0
# 3          0          2   465  ANG MO KIO AVE 10             1
# 4          0          2   601   ANG MO KIO AVE 5             0
# ...      ...        ...   ...                ...           ...
# 168473    25          5   606       YISHUN ST 61             2
# 168474    25          5   643       YISHUN ST 61             3
# 168475    25          5   643       YISHUN ST 61             3
# 168476    25          5   826       YISHUN ST 81             0
# 168477    25          5   834       YISHUN ST 81             0
#
#         floor_area_sqm  flat_model  resale_price  year  month_of_year  \
# 0                 44.0           5      232000.0  2017              1
# 1                 67.0          12      250000.0  2017              1
# 2                 67.0          12      262000.0  2017              1
# 3                 68.0          12      265000.0  2017              1
# 4                 67.0          12      265000.0  2017              1
# ...                ...         ...           ...   ...            ...
# 168473           142.0           3      788888.0  2023             12
# 168474           146.0           7      838000.0  2023             12
# 168475           142.0           3      755000.0  2023             12
# 168476           142.0           3      780000.0  2023             12
# 168477           142.0           3      785000.0  2023             12
#
#         lease_commence_year  remaining_lease_years  remaining_lease_months
# 0                      1979              61.000000                4.000000
# 1                      1978              60.000000                7.000000
# 2                      1980              62.000000                5.000000
# 3                      1980              74.123433                6.534301
# 4                      1980              62.000000                5.000000
# ...                     ...                    ...                     ...
# 168473                 1987              74.123433                6.534301
# 168474                 1987              62.000000               10.000000
# 168475                 1987              62.000000               10.000000
# 168476                 1988              63.000000                2.000000
# 168477                 1988              63.000000                2.000000
#
# [168478 rows x 13 columns]

# %%
# after encoding descriptive statistics analaysis

house_new_data.describe().T
# Out:
#                            count           mean            std       min  \
# town                    168478.0      14.002534       7.930095       0.0
# flat_type               168478.0       3.130694       0.918923       0.0
# storey_range            168478.0       2.255654       1.983129       0.0
# floor_area_sqm          168478.0      97.295905      24.021881      31.0
# flat_model              168478.0       8.652103       3.631067       0.0
# resale_price            168478.0  490609.627139  169704.579381  140000.0
# year                    168478.0    2020.183632       1.962744    2017.0
# month_of_year           168478.0       6.687544       3.383811       1.0
# lease_commence_year     168478.0    1995.849399      13.937598    1966.0
# remaining_lease_years   168478.0      74.123433      12.653194      42.0
# remaining_lease_months  168478.0       6.534301       2.641197       0.0
#
#                              25%            50%       75%        max
# town                         8.0      15.000000      21.0       25.0
# flat_type                    2.0       3.000000       4.0        6.0
# storey_range                 1.0       2.000000       3.0       16.0
# floor_area_sqm              82.0      93.000000     112.0      249.0
# flat_model                   5.0       8.000000      12.0       20.0
# resale_price            365000.0  460000.000000  582000.0  1500000.0
# year                      2019.0    2020.000000    2022.0     2023.0
# month_of_year                4.0       7.000000      10.0       12.0
# lease_commence_year       1985.0    1996.000000    2009.0     2022.0
# remaining_lease_years       64.0      74.123433      83.0       97.0
# remaining_lease_months       5.0       6.534301       9.0       11.0

# %% [markdown]
# # Skewness Handling

# %%
# checking the outliars using boxplot distribution plot

def plot(house_new_data,column):
    plt.figure(figsize =(15,6))
    plt.subplot(1,3,1)
    sns.boxplot(data = house_new_data ,x = column)
    plt.title(f'box plot for {column}')
    

    plt.subplot(1,3,2)
    sns.histplot(data = house_new_data ,x = column,kde = True ,bins = 40)
    plt.title(f'distribution  plot for {column}')
    plt.show()

# %%
for i in ['floor_area_sqm','resale_price','lease_commence_year','remaining_lease_years']:
    plot(house_new_data ,i)

# %%
# 'floor_area_sqm','resale_price' this two feature are skewd in data handling log method 


house_new_data['floor_area_sqm'] = np.log(house_new_data['floor_area_sqm'])
house_new_data['resale_price'] = np.log(house_new_data['resale_price'])
house_new_data
# Out:
#         town  flat_type block        street_name  storey_range  \
# 0          0          1   406  ANG MO KIO AVE 10             3
# 1          0          2   108   ANG MO KIO AVE 4             0
# 2          0          2   602   ANG MO KIO AVE 5             0
# 3          0          2   465  ANG MO KIO AVE 10             1
# 4          0          2   601   ANG MO KIO AVE 5             0
# ...      ...        ...   ...                ...           ...
# 168473    25          5   606       YISHUN ST 61             2
# 168474    25          5   643       YISHUN ST 61             3
# 168475    25          5   643       YISHUN ST 61             3
# 168476    25          5   826       YISHUN ST 81             0
# 168477    25          5   834       YISHUN ST 81             0
#
#         floor_area_sqm  flat_model  resale_price  year  month_of_year  \
# 0             3.784190           5     12.354493  2017              1
# 1             4.204693          12     12.429216  2017              1
# 2             4.204693          12     12.476100  2017              1
# 3             4.219508          12     12.487485  2017              1
# 4             4.204693          12     12.487485  2017              1
# ...                ...         ...           ...   ...            ...
# 168473        4.955827           3     13.578380  2023             12
# 168474        4.983607           7     13.638773  2023             12
# 168475        4.955827           3     13.534473  2023             12
# 168476        4.955827           3     13.567049  2023             12
# 168477        4.955827           3     13.573439  2023             12
#
#         lease_commence_year  remaining_lease_years  remaining_lease_months
# 0                      1979              61.000000                4.000000
# 1                      1978              60.000000                7.000000
# 2                      1980              62.000000                5.000000
# 3                      1980              74.123433                6.534301
# 4                      1980              62.000000                5.000000
# ...                     ...                    ...                     ...
# 168473                 1987              74.123433                6.534301
# 168474                 1987              62.000000               10.000000
# 168475                 1987              62.000000               10.000000
# 168476                 1988              63.000000                2.000000
# 168477                 1988              63.000000                2.000000
#
# [168478 rows x 13 columns]

# %%
for i in ['floor_area_sqm','resale_price']:
    plot(house_new_data,i)

# %% [markdown]
# # Treat Outliers using IQR

# %%
#using the IQR & Clips  method removing the outliars :
# formula IQR = Q3_Q1
def outlier(house_new_data ,column):
    IQR = house_new_data[column].quantile(0.75)-house_new_data[column].quantile(0.25)
    upper_value = house_new_data[column].quantile(0.75)+1.5*IQR
    lower_value = house_new_data[column].quantile(0.25)-1.5*IQR
    
    house_new_data[column] =     house_new_data[column].clip(upper_value,lower_value)

outlier(house_new_data, 'floor_area_sqm')
outlier(house_new_data, 'resale_price')
house_new_data1 = house_new_data.copy()

# %%
house_new_data1
# Out:
#         town  flat_type block        street_name  storey_range  \
# 0          0          1   406  ANG MO KIO AVE 10             3
# 1          0          2   108   ANG MO KIO AVE 4             0
# 2          0          2   602   ANG MO KIO AVE 5             0
# 3          0          2   465  ANG MO KIO AVE 10             1
# 4          0          2   601   ANG MO KIO AVE 5             0
# ...      ...        ...   ...                ...           ...
# 168473    25          5   606       YISHUN ST 61             2
# 168474    25          5   643       YISHUN ST 61             3
# 168475    25          5   643       YISHUN ST 61             3
# 168476    25          5   826       YISHUN ST 81             0
# 168477    25          5   834       YISHUN ST 81             0
#
#         floor_area_sqm  flat_model  resale_price  year  month_of_year  \
# 0             3.939050           5     12.354493  2017              1
# 1             4.204693          12     12.429216  2017              1
# 2             4.204693          12     12.476100  2017              1
# 3             4.219508          12     12.487485  2017              1
# 4             4.204693          12     12.487485  2017              1
# ...                ...         ...           ...   ...            ...
# 168473        4.955827           3     13.578380  2023             12
# 168474        4.983607           7     13.638773  2023             12
# 168475        4.955827           3     13.534473  2023             12
# 168476        4.955827           3     13.567049  2023             12
# 168477        4.955827           3     13.573439  2023             12
#
#         lease_commence_year  remaining_lease_years  remaining_lease_months
# 0                      1979              61.000000                4.000000
# 1                      1978              60.000000                7.000000
# 2                      1980              62.000000                5.000000
# 3                      1980              74.123433                6.534301
# 4                      1980              62.000000                5.000000
# ...                     ...                    ...                     ...
# 168473                 1987              74.123433                6.534301
# 168474                 1987              62.000000               10.000000
# 168475                 1987              62.000000               10.000000
# 168476                 1988              63.000000                2.000000
# 168477                 1988              63.000000                2.000000
#
# [168478 rows x 13 columns]

# %%
# after IQR using checking the skewness
for i in ['floor_area_sqm','resale_price']:
    plot(house_new_data1,i)

# %%
plt.figure(figsize= (15,6))
sns.barplot(y = 'flat_model', x= 'resale_price',data = house )
# Out:
# <Axes: xlabel='resale_price', ylabel='flat_model'>

# %%
plt.figure(figsize= (15,6))
sns.barplot(y = 'town', x= 'resale_price',data = house )
# Out:
# <Axes: xlabel='resale_price', ylabel='town'>

# %% [markdown]
# # Basic EDA

# %%
plt.figure(figsize= (15,6))
sns.barplot(y = 'flat_type', x= 'resale_price',data = house )
# Out:
# <Axes: xlabel='resale_price', ylabel='flat_type'>

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = 'resale_price' ,y = 'floor_area_sqm',data = house)
# Out:
# <Axes: xlabel='resale_price', ylabel='floor_area_sqm'>

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'lease_commence_year' , y = 'resale_price', data = house_new_data)
# Out:
# <Axes: xlabel='lease_commence_year', ylabel='resale_price'>

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'year', y = 'resale_price', data = house_new_data)
# Out:
# <Axes: xlabel='year', ylabel='resale_price'>

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'remaining_lease_years' , y = 'resale_price', data = house_new_data)
# Out:
# <Axes: xlabel='remaining_lease_years', ylabel='resale_price'>

# %%
# dropping the irrelvent feature 
house_new_data1.drop(columns=['block','street_name'],inplace = True)
house_new_data1
# Out:
#         town  flat_type  storey_range  floor_area_sqm  flat_model  \
# 0          0          1             3        3.939050           5
# 1          0          2             0        4.204693          12
# 2          0          2             0        4.204693          12
# 3          0          2             1        4.219508          12
# 4          0          2             0        4.204693          12
# ...      ...        ...           ...             ...         ...
# 168473    25          5             2        4.955827           3
# 168474    25          5             3        4.983607           7
# 168475    25          5             3        4.955827           3
# 168476    25          5             0        4.955827           3
# 168477    25          5             0        4.955827           3
#
#         resale_price  year  month_of_year  lease_commence_year  \
# 0          12.354493  2017              1                 1979
# 1          12.429216  2017              1                 1978
# 2          12.476100  2017              1                 1980
# 3          12.487485  2017              1                 1980
# 4          12.487485  2017              1                 1980
# ...              ...   ...            ...                  ...
# 168473     13.578380  2023             12                 1987
# 168474     13.638773  2023             12                 1987
# 168475     13.534473  2023             12                 1987
# 168476     13.567049  2023             12                 1988
# 168477     13.573439  2023             12                 1988
#
#         remaining_lease_years  remaining_lease_months
# 0                   61.000000                4.000000
# 1                   60.000000                7.000000
# 2                   62.000000                5.000000
# 3                   74.123433                6.534301
# 4                   62.000000                5.000000
# ...                       ...                     ...
# 168473              74.123433                6.534301
# 168474              62.000000               10.000000
# 168475              62.000000               10.000000
# 168476              63.000000                2.000000
# 168477              63.000000                2.000000
#
# [168478 rows x 11 columns]

# %%
house_new_data1
# Out:
#         town  flat_type  storey_range  floor_area_sqm  flat_model  \
# 0          0          1             3        3.939050           5
# 1          0          2             0        4.204693          12
# 2          0          2             0        4.204693          12
# 3          0          2             1        4.219508          12
# 4          0          2             0        4.204693          12
# ...      ...        ...           ...             ...         ...
# 168473    25          5             2        4.955827           3
# 168474    25          5             3        4.983607           7
# 168475    25          5             3        4.955827           3
# 168476    25          5             0        4.955827           3
# 168477    25          5             0        4.955827           3
#
#         resale_price  year  month_of_year  lease_commence_year  \
# 0          12.354493  2017              1                 1979
# 1          12.429216  2017              1                 1978
# 2          12.476100  2017              1                 1980
# 3          12.487485  2017              1                 1980
# 4          12.487485  2017              1                 1980
# ...              ...   ...            ...                  ...
# 168473     13.578380  2023             12                 1987
# 168474     13.638773  2023             12                 1987
# 168475     13.534473  2023             12                 1987
# 168476     13.567049  2023             12                 1988
# 168477     13.573439  2023             12                 1988
#
#         remaining_lease_years  remaining_lease_months
# 0                   61.000000                4.000000
# 1                   60.000000                7.000000
# 2                   62.000000                5.000000
# 3                   74.123433                6.534301
# 4                   62.000000                5.000000
# ...                       ...                     ...
# 168473              74.123433                6.534301
# 168474              62.000000               10.000000
# 168475              62.000000               10.000000
# 168476              63.000000                2.000000
# 168477              63.000000                2.000000
#
# [168478 rows x 11 columns]

# %%
house_new_data1.dtypes
# Out:
# town                        int32
# flat_type                   int32
# storey_range                int32
# floor_area_sqm            float64
# flat_model                  int32
# resale_price              float64
# year                        int32
# month_of_year               int32
# lease_commence_year         int32
# remaining_lease_years     float64
# remaining_lease_months    float64
# dtype: object

# %%
heat = house_new_data1.corr()
heat
# Out:
#                             town  flat_type  storey_range  floor_area_sqm  \
# town                    1.000000   0.100979     -0.054408        0.097313
# flat_type               0.100979   1.000000      0.031684        0.946522
# storey_range           -0.054408   0.031684      1.000000        0.003667
# floor_area_sqm          0.097313   0.946522      0.003667        1.000000
# flat_model             -0.085571  -0.327329     -0.039726       -0.325402
# resale_price           -0.019062   0.662433      0.330982        0.663578
# year                    0.011474  -0.022518      0.019027       -0.026566
# month_of_year           0.009634   0.003039     -0.003031        0.000573
# lease_commence_year     0.216893   0.188445      0.277143        0.167654
# remaining_lease_years   0.196729   0.177429      0.253172        0.159012
# remaining_lease_months  0.006259  -0.001219     -0.002756       -0.002174
#
#                         flat_model  resale_price      year  month_of_year  \
# town                     -0.085571     -0.019062  0.011474       0.009634
# flat_type                -0.327329      0.662433 -0.022518       0.003039
# storey_range             -0.039726      0.330982  0.019027      -0.003031
# floor_area_sqm           -0.325402      0.663578 -0.026566       0.000573
# flat_model                1.000000     -0.246338 -0.013229      -0.007236
# resale_price             -0.246338      1.000000  0.304462       0.020825
# year                     -0.013229      0.304462  1.000000      -0.049237
# month_of_year            -0.007236      0.020825 -0.049237       1.000000
# lease_commence_year      -0.122528      0.407279  0.130505       0.012596
# remaining_lease_years    -0.112663      0.335725 -0.007771      -0.012631
# remaining_lease_months    0.000707      0.004297  0.008193       0.017684
#
#                         lease_commence_year  remaining_lease_years  \
# town                               0.216893               0.196729
# flat_type                          0.188445               0.177429
# storey_range                       0.277143               0.253172
# floor_area_sqm                     0.167654               0.159012
# flat_model                        -0.122528              -0.112663
# resale_price                       0.407279               0.335725
# year                               0.130505              -0.007771
# month_of_year                      0.012596              -0.012631
# lease_commence_year                1.000000               0.903909
# remaining_lease_years              0.903909               1.000000
# remaining_lease_months             0.014981              -0.003182
#
#                         remaining_lease_months
# town                                  0.006259
# flat_type                            -0.001219
# storey_range                         -0.002756
# floor_area_sqm                       -0.002174
# flat_model                            0.000707
# resale_price                          0.004297
# year                                  0.008193
# month_of_year                         0.017684
# lease_commence_year                   0.014981
# remaining_lease_years                -0.003182
# remaining_lease_months                1.000000

# %%
# Need to verify any columns are highly correlated using Heatmap
plt.figure(figsize=(15,6))
sns.heatmap(heat,annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # Model Buliding:

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model   import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV
import pickle

# %%
house_new_data1.columns
# Out:
# Index(['town', 'flat_type', 'storey_range', 'floor_area_sqm', 'flat_model',
#        'resale_price', 'year', 'month_of_year', 'lease_commence_year',
#        'remaining_lease_years', 'remaining_lease_months'],
#       dtype='object')

# %%
x = house_new_data1[['town', 'flat_type', 'storey_range', 'floor_area_sqm', 'flat_model',
        'year', 'month_of_year', 'lease_commence_year',
       'remaining_lease_years', 'remaining_lease_months']]
y = house_new_data1[['resale_price']]

# %%
#standardize the features of a dataset
encoder = StandardScaler()

encoder.fit_transform(x)
# Out:
# array([[-1.76575146, -2.31869261,  0.3753405 , ..., -1.20892055,
#         -1.03716671, -0.9595305 ],
#        [-1.76575146, -1.23045891, -1.13742484, ..., -1.28066914,
#         -1.11619837,  0.17632171],
#        [-1.76575146, -1.23045891, -1.13742484, ..., -1.13717197,
#         -0.95813505, -0.5809131 ],
#        ...,
#        [ 1.38680543,  2.0342422 ,  0.3753405 , ..., -0.63493186,
#         -0.95813505,  1.31217391],
#        [ 1.38680543,  2.0342422 , -1.13742484, ..., -0.56318327,
#         -0.87910339, -1.7167653 ],
#        [ 1.38680543,  2.0342422 , -1.13742484, ..., -0.56318327,
#         -0.87910339, -1.7167653 ]])

# %%
#check the accuracy of training and testing using metrics RandomForestRegressor


x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)
x_train.shape,x_test.shape

RFR = RandomForestRegressor()

RFR= RandomForestRegressor(n_estimators= 50 ,random_state = 0)

# fitting the model: 

RFR.fit(x_train,y_train)

y_pred_train = RFR.predict(x_train)
y_pred_test = RFR.predict(x_test)

r2_train = r2_score(y_train,y_pred_train)
r2_test = r2_score(y_test,y_pred_test)

r2_train,r2_test
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# (0.9928023689962114, 0.9546702060052777)

# %%
# we got good accuracy after oversampling
# RandomForestRegressor have good testing accuracy, but in training accuracy is overfitting.

# %%
# GridsearchCV is a cross validation function
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)

param = {'max_depth'        : [20],
              'min_samples_split': [ 5, ],
              'min_samples_leaf' : [ 2, ],
              'max_features'     : ['log2']}
grid_searchcv = GridSearchCV(RandomForestRegressor(),param_grid = param,  cv = 5)
grid_searchcv.fit(x_train, y_train)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [20], 'max_features': ['log2'],
#                          'min_samples_leaf': [2], 'min_samples_split': [5]})

# %%
grid_searchcv.best_score_
# Out:
# 0.9256823656506279

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)
x_train.shape,x_test.shape

RFR = RandomForestRegressor()

Hyper_model= RandomForestRegressor(max_depth= 20 ,max_features='log2' ,min_samples_leaf=2, min_samples_split=5)

# fitting the model: 

Hyper_model.fit(x_train,y_train)

y_pred_train = Hyper_model.predict(x_train)
y_pred_test = Hyper_model.predict(x_test)

r2_train = r2_score(y_train,y_pred_train)
r2_test = r2_score(y_test,y_pred_test)

r2_train,r2_test
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# (0.9574673276520979, 0.9294984979587266)

# %%
# now the training accuracy overfitting reduced. so now model will predict effectively for unseen data

# %%
# predict the selling price with hypertuning parameters and calculate the accuracy using metrics

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)
x_train.shape,x_test.shape

RFR = RandomForestRegressor()

Hyper_model= RandomForestRegressor(max_depth= 20 ,max_features='log2' ,min_samples_leaf=2, min_samples_split=5)

# fitting the model: 

Hyper_model.fit(x_train,y_train)

y_pred_train = Hyper_model.predict(x_train)
y_pred_test = Hyper_model.predict(x_test)                      
print('Mean Squared Error:' ,mean_squared_error(y_test,y_pred_test))
print('Mean Absolute Error:',mean_absolute_error(y_test,y_pred_test))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,y_pred_test)))
print(r2_score(y_test,y_pred_test))
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Mean Squared Error: 0.0077643719253624455
# Mean Absolute Error: 0.06376434335111976
# Root Mean Squared Error: 0.08811567355109104
# 0.9309897198777668

# %%
# manually passed the user input and predict the selling price

user_data = np.array([[0,1,3,3.785069,5,2017,1,1979,61.000000,4.000000]])
y_prediction = Hyper_model.predict(user_data)
y_prediction[0]
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 12.371147597113376

# %%
user_data = np.array([[4,3,2,4.785069,4,2023,3,1989,69.000000,4.000000]])

y_prediction = Hyper_model.predict(user_data)
y_prediction[0]
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 13.53281679688504

# %%
# using Inverse Log Transformation to convert the value to original re sale price of the data (exp)
np.exp(y_prediction[0])
# Out:
# 753750.580283335

# %%
# save the regression model by using pickle

with open("C:\\Users\\User\\OneDrive\\Desktop\\project files\\house_price_model.pkl", 'wb') as f:
    pickle.dump(Hyper_model, f)

# %%
# load the model
with open("C:\\Users\\User\\OneDrive\\Desktop\\project files\\house_price_model.pkl", 'rb') as f:
    model = pickle.load(f)

user_data = np.array([[4, 3, 2, 4.785069, 4, 2023, 3, 1989, 69.000000, 4.000000]])
prediction = model.predict(user_data)
predicted_price = prediction[0]
predicted_price
np.exp(predicted_price)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 753750.580283335
